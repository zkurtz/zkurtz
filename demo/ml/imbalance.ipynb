# %% [markdown]
# # Dealing with imbalanced data
#
# Several generic ML tricks have been proposed to improve the performance of classifiers trained on highly imbalanced data sets. We will try some of these on simulated data to see if we can replicate such improvement.

# %%
from sklearn.datasets import make_classification
